# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from utils import plot_logits

# %%
df = pd.concat([pd.read_csv("output_4bit.csv"), pd.read_csv("output_8bit.csv")])

# %%
tmp_df = df[(df['n'] <= 11) & (df['Prompt'] == 'The most important thing in life is')]

# %%
top_words = tmp_df[tmp_df['Quantisation'] == '8bit']['Top n Words'].to_list()

# %%
tmp_df[tmp_df['Quantisation'] == '4bit']['Top n Words'].isin(top_words)
# Out:
# 300     True
# 301     True
# 302    False
# 303     True
# 304     True
# 305    False
# 306     True
# 307     True
# 308    False
# 309     True
# 310     True
# Name: Top n Words, dtype: bool

# %%
fig = plot_logits(df, "The capital of France is", 5)
